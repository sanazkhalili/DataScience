# %%
# !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: sqlparse in c:\users\microsoft\anaconda3\lib\site-packages (from ipython-sql) (0.4.4)
# Collecting prettytable
#   Downloading prettytable-3.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: six in c:\users\microsoft\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython in c:\users\microsoft\anaconda3\lib\site-packages (from ipython-sql) (7.31.1)
# Collecting sqlalchemy>=2.0
#   Using cached SQLAlchemy-2.0.12-cp39-cp39-win_amd64.whl (2.0 MB)
# Requirement already satisfied: ipython-genutils in c:\users\microsoft\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\microsoft\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\microsoft\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.3.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.20)
# Requirement already satisfied: traitlets>=4.2 in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: decorator in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: colorama in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.5)
# Requirement already satisfied: pygments in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (63.4.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: backcall in c:\users\microsoft\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\microsoft\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\microsoft\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Installing collected packages: sqlalchemy, prettytable, ipython-sql
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
# Successfully installed ipython-sql-0.5.0 prettytable-3.7.0 sqlalchemy-2.0.12

# %%
# !pip install PyMySQL

# %%
import sqlalchemy
import pymysql

pymysql.install_as_MySQLdb()

engine = sqlalchemy.create_engine('mysql+mysqldb://root:sanaz11@covid') # connect to server

# %%
# %load_ext sql

# Connect to the database
# %sql  mysql://root:sanaz11@localhost:3306/classicmodels
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.displaycon = False

# %%
# %sql select * from orders
# Out:
# 326 rows affected.
# [(10100, datetime.date(2022, 2, 1), datetime.date(2003, 1, 13), datetime.date(2003, 1, 10), 'Shipped', None, 363, 20),
#  (10101, datetime.date(2022, 3, 1), datetime.date(2003, 1, 18), datetime.date(2003, 1, 11), 'Shipped', 'Check on availability.', 128, 20),
#  (10102, datetime.date(2022, 2, 1), datetime.date(2003, 1, 18), datetime.date(2003, 1, 14), 'Shipped', None, 181, 20),
#  (10103, datetime.date(2022, 3, 8), datetime.date(2003, 2, 7), datetime.date(2003, 2, 2), 'Shipped', None, 121, 20),
#  (10104, datetime.date(2003, 1, 31), datetime.date(2003, 2, 9), datetime.date(2003, 2, 1), 'Shipped', None, 141, 20),
#  (10105, datetime.date(2003, 2, 11), datetime.date(2003, 2, 21), datetime.date(2003, 2, 12), 'Shipped', None, 145, 20),
#  (10106, datetime.date(2003, 2, 17), datetime.date(2003, 2, 24), datetime.date(2003, 2, 21), 'Shipped', None, 278, 20),
#  (10107, datetime.date(2003, 2, 24), datetime.date(2003, 3, 3), datetime.date(2003, 2, 26), 'Shipped', 'Difficult to negotiate with customer. We need more marketing materials', 131, 20),
#  (10108, datetime.date(2003, 3, 3), datetime.date(2003, 3, 12), datetime.date(2003, 3, 8), 'Shipped', None, 385, 20),
#  (10109, datetime.date(2003, 3, 10), datetime.date(2003, 3, 19), datetime.date(2003, 3, 11), 'Shipped', 'Customer requested that FedEx Ground is used for this shipping', 486, 20),
#  (10110, datetime.date(2003, 3, 18), datetime.date(2003, 3, 24), datetime.date(2003, 3, 20), 'Shipped', None, 187, 20),
#  (10111, datetime.date(2003, 3, 25), datetime.date(2003, 3, 31), datetime.date(2003, 3, 30), 'Shipped', None, 129, 20),
#  (10112, datetime.date(2003, 3, 24), datetime.date(2003, 4, 3), datetime.date(2003, 3, 29), 'Shipped', 'Customer requested that ad materials (such as posters, pamphlets) be included in the shippment', 144, 20),
#  (10113, datetime.date(2003, 3, 26), datetime.date(2003, 4, 2), datetime.date(2003, 3, 27), 'Shipped', None, 124, 20),
#  (10114, datetime.date(2003, 4, 1), datetime.date(2003, 4, 7), datetime.date(2003, 4, 2), 'Shipped', None, 172, 20),
#  (10115, datetime.date(2003, 4, 4), datetime.date(2003, 4, 12), datetime.date(2003, 4, 7), 'Shipped', None, 424, 20),
#  (10116, datetime.date(2003, 4, 11), datetime.date(2003, 4, 19), datetime.date(2003, 4, 13), 'Shipped', None, 381, 20),
#  (10117, datetime.date(2003, 4, 16), datetime.date(2003, 4, 24), datetime.date(2003, 4, 17), 'Shipped', None, 148, 20),
#  (10118, datetime.date(2003, 4, 21), datetime.date(2003, 4, 29), datetime.date(2003, 4, 26), 'Shipped', 'Customer has worked with some of our vendors in the past and is aware of their MSRP', 216, 20),
#  (10119, datetime.date(2003, 4, 28), datetime.date(2003, 5, 5), datetime.date(2003, 5, 2), 'Shipped', None, 382, 20),
#  (10120, datetime.date(2003, 4, 29), datetime.date(2003, 5, 8), datetime.date(2003, 5, 1), 'Shipped', None, 114, 20),
#  (10121, datetime.date(2003, 5, 7), datetime.date(2003, 5, 13), datetime.date(2003, 5, 13), 'Shipped', None, 353, 20),
#  (10122, datetime.date(2003, 5, 8), datetime.date(2003, 5, 16), datetime.date(2003, 5, 13), 'Shipped', None, 350, 20),
#  (10123, datetime.date(2003, 5, 20), datetime.date(2003, 5, 29), datetime.date(2003, 5, 22), 'Shipped', None, 103, 20),
#  (10124, datetime.date(2003, 5, 21), datetime.date(2003, 5, 29), datetime.date(2003, 5, 25), 'Shipped', 'Customer very concerned about the exact color of the models. There is high risk that he may dispute the order because there is a slight color mismatch', 112, 20),
#  (10125, datetime.date(2003, 5, 21), datetime.date(2003, 5, 27), datetime.date(2003, 5, 24), 'Shipped', None, 114, 20),
#  (10126, datetime.date(2003, 5, 28), datetime.date(2003, 6, 7), datetime.date(2003, 6, 2), 'Shipped', None, 458, 20),
#  (10127, datetime.date(2003, 6, 3), datetime.date(2003, 6, 9), datetime.date(2003, 6, 6), 'Shipped', 'Customer requested special shippment. The instructions were passed along to the warehouse', 151, 20),
#  (10128, datetime.date(2003, 6, 6), datetime.date(2003, 6, 12), datetime.date(2003, 6, 11), 'Shipped', None, 141, 20),
#  (10129, datetime.date(2003, 6, 12), datetime.date(2003, 6, 18), datetime.date(2003, 6, 14), 'Shipped', None, 324, 20),
#  (10130, datetime.date(2003, 6, 16), datetime.date(2003, 6, 24), datetime.date(2003, 6, 21), 'Shipped', None, 198, 20),
#  (10131, datetime.date(2003, 6, 16), datetime.date(2003, 6, 25), datetime.date(2003, 6, 21), 'Shipped', None, 447, 20),
#  (10132, datetime.date(2003, 6, 25), datetime.date(2003, 7, 1), datetime.date(2003, 6, 28), 'Shipped', None, 323, 20),
#  (10133, datetime.date(2003, 6, 27), datetime.date(2003, 7, 4), datetime.date(2003, 7, 3), 'Shipped', None, 141, 20),
#  (10134, datetime.date(2003, 7, 1), datetime.date(2003, 7, 10), datetime.date(2003, 7, 5), 'Shipped', None, 250, 20),
#  (10135, datetime.date(2003, 7, 2), datetime.date(2003, 7, 12), datetime.date(2003, 7, 3), 'Shipped', None, 124, 20),
#  (10136, datetime.date(2003, 7, 4), datetime.date(2003, 7, 14), datetime.date(2003, 7, 6), 'Shipped', 'Customer is interested in buying more Ferrari models', 242, 20),
#  (10137, datetime.date(2003, 7, 10), datetime.date(2003, 7, 20), datetime.date(2003, 7, 14), 'Shipped', None, 353, 20),
#  (10138, datetime.date(2003, 7, 7), datetime.date(2003, 7, 16), datetime.date(2003, 7, 13), 'Shipped', None, 496, 20),
#  (10139, datetime.date(2003, 7, 16), datetime.date(2003, 7, 23), datetime.date(2003, 7, 21), 'Shipped', None, 282, 20),
#  (10140, datetime.date(2003, 7, 24), datetime.date(2003, 8, 2), datetime.date(2003, 7, 30), 'Shipped', None, 161, 20),
#  (10141, datetime.date(2003, 8, 1), datetime.date(2003, 8, 9), datetime.date(2003, 8, 4), 'Shipped', None, 334, 20),
#  (10142, datetime.date(2003, 8, 8), datetime.date(2003, 8, 16), datetime.date(2003, 8, 13), 'Shipped', None, 124, 20),
#  (10143, datetime.date(2003, 8, 10), datetime.date(2003, 8, 18), datetime.date(2003, 8, 12), 'Shipped', 'Can we deliver the new Ford Mustang models by end-of-quarter?', 320, 20),
#  (10144, datetime.date(2003, 8, 13), datetime.date(2003, 8, 21), datetime.date(2003, 8, 14), 'Shipped', None, 381, 20),
#  (10145, datetime.date(2003, 8, 25), datetime.date(2003, 9, 2), datetime.date(2003, 8, 31), 'Shipped', None, 205, 20),
#  (10146, datetime.date(2003, 9, 3), datetime.date(2003, 9, 13), datetime.date(2003, 9, 6), 'Shipped', None, 447, 20),
#  (10147, datetime.date(2003, 9, 5), datetime.date(2003, 9, 12), datetime.date(2003, 9, 9), 'Shipped', None, 379, 20),
#  (10148, datetime.date(2003, 9, 11), datetime.date(2003, 9, 21), datetime.date(2003, 9, 15), 'Shipped', 'They want to reevaluate their terms agreement with Finance.', 276, 20),
#  (10149, datetime.date(2003, 9, 12), datetime.date(2003, 9, 18), datetime.date(2003, 9, 17), 'Shipped', None, 487, 20),
#  (10150, datetime.date(2003, 9, 19), datetime.date(2003, 9, 27), datetime.date(2003, 9, 21), 'Shipped', 'They want to reevaluate their terms agreement with Finance.', 148, 20),
#  (10151, datetime.date(2003, 9, 21), datetime.date(2003, 9, 30), datetime.date(2003, 9, 24), 'Shipped', None, 311, 20),
#  (10152, datetime.date(2003, 9, 25), datetime.date(2003, 10, 3), datetime.date(2003, 10, 1), 'Shipped', None, 333, 20),
#  (10153, datetime.date(2003, 9, 28), datetime.date(2003, 10, 5), datetime.date(2003, 10, 3), 'Shipped', None, 141, 20),
#  (10154, datetime.date(2003, 10, 2), datetime.date(2003, 10, 12), datetime.date(2003, 10, 8), 'Shipped', None, 219, 20),
#  (10155, datetime.date(2003, 10, 6), datetime.date(2003, 10, 13), datetime.date(2003, 10, 7), 'Shipped', None, 186, 20),
#  (10156, datetime.date(2003, 10, 8), datetime.date(2003, 10, 17), datetime.date(2003, 10, 11), 'Shipped', None, 141, 20),
#  (10157, datetime.date(2003, 10, 9), datetime.date(2003, 10, 15), datetime.date(2003, 10, 14), 'Shipped', None, 473, 20),
#  (10158, datetime.date(2022, 3, 8), datetime.date(2003, 10, 18), datetime.date(2003, 10, 15), 'Shipped', None, 121, 20),
#  (10159, datetime.date(2003, 10, 10), datetime.date(2003, 10, 19), datetime.date(2003, 10, 16), 'Shipped', None, 321, 20),
#  (10160, datetime.date(2003, 10, 11), datetime.date(2003, 10, 17), datetime.date(2003, 10, 17), 'Shipped', None, 347, 20),
#  (10161, datetime.date(2003, 10, 17), datetime.date(2003, 10, 25), datetime.date(2003, 10, 20), 'Shipped', None, 227, 20),
#  (10162, datetime.date(2003, 10, 18), datetime.date(2003, 10, 26), datetime.date(2003, 10, 19), 'Shipped', None, 321, 20),
#  (10163, datetime.date(2003, 10, 20), datetime.date(2003, 10, 27), datetime.date(2003, 10, 24), 'Shipped', None, 424, 20),
#  (10164, datetime.date(2003, 10, 21), datetime.date(2003, 10, 30), datetime.date(2003, 10, 23), 'Resolved', "This order was disputed, but resolved on 11/1/2003; Customer doesn't like the colors and precision of the models.", 452, 20),
#  (10165, datetime.date(2003, 10, 22), datetime.date(2003, 10, 31), datetime.date(2003, 12, 26), 'Shipped', "This order was on hold because customers's credit limit had been exceeded. Order will ship when payment is received", 148, 20),
#  (10166, datetime.date(2003, 10, 21), datetime.date(2003, 10, 30), datetime.date(2003, 10, 27), 'Shipped', None, 462, 20),
#  (10167, datetime.date(2003, 10, 23), datetime.date(2003, 10, 30), None, 'Cancelled', "Customer called to cancel. The warehouse was notified in time and the order didn't ship. They have a new VP of Sales and are shifting their sales model. Our VP of Sales should contact them.", 448, 20),
#  (10168, datetime.date(2003, 10, 28), datetime.date(2003, 11, 3), datetime.date(2003, 11, 1), 'Shipped', None, 161, 20),
#  (10169, datetime.date(2003, 11, 4), datetime.date(2003, 11, 14), datetime.date(2003, 11, 9), 'Shipped', None, 276, 20),
#  (10170, datetime.date(2003, 11, 4), datetime.date(2003, 11, 12), datetime.date(2003, 11, 7), 'Shipped', None, 452, 20),
#  (10171, datetime.date(2003, 11, 5), datetime.date(2003, 11, 13), datetime.date(2003, 11, 7), 'Shipped', None, 233, 20),
#  (10172, datetime.date(2003, 11, 5), datetime.date(2003, 11, 14), datetime.date(2003, 11, 11), 'Shipped', None, 175, 20),
#  (10173, datetime.date(2003, 11, 5), datetime.date(2003, 11, 15), datetime.date(2003, 11, 9), 'Shipped', 'Cautious optimism. We have happy customers here, if we can keep them well stocked.  I need all the information I can get on the planned shippments of Porches', 278, 20),
#  (10174, datetime.date(2003, 11, 6), datetime.date(2003, 11, 15), datetime.date(2003, 11, 10), 'Shipped', None, 333, 20),
#  (10175, datetime.date(2003, 11, 6), datetime.date(2003, 11, 14), datetime.date(2003, 11, 9), 'Shipped', None, 324, 20),
#  (10176, datetime.date(2003, 11, 6), datetime.date(2003, 11, 15), datetime.date(2003, 11, 12), 'Shipped', None, 386, 20),
#  (10177, datetime.date(2003, 11, 7), datetime.date(2003, 11, 17), datetime.date(2003, 11, 12), 'Shipped', None, 344, 20),
#  (10178, datetime.date(2003, 11, 8), datetime.date(2003, 11, 16), datetime.date(2003, 11, 10), 'Shipped', 'Custom shipping instructions sent to warehouse', 242, 20),
#  (10179, datetime.date(2003, 11, 11), datetime.date(2003, 11, 17), datetime.date(2003, 11, 13), 'Cancelled', 'Customer cancelled due to urgent budgeting issues. Must be cautious when dealing with them in the future. Since order shipped already we must discuss who would cover the shipping charges.', 496, 20),
#  (10180, datetime.date(2003, 11, 11), datetime.date(2003, 11, 19), datetime.date(2003, 11, 14), 'Shipped', None, 171, 20),
#  (10181, datetime.date(2003, 11, 12), datetime.date(2003, 11, 19), datetime.date(2003, 11, 15), 'Shipped', None, 167, 20),
#  (10182, datetime.date(2003, 11, 12), datetime.date(2003, 11, 21), datetime.date(2003, 11, 18), 'Shipped', None, 124, 20),
#  (10183, datetime.date(2003, 11, 13), datetime.date(2003, 11, 22), datetime.date(2003, 11, 15), 'Shipped', 'We need to keep in close contact with their Marketing VP. He is the decision maker for all their purchases.', 339, 20),
#  (10184, datetime.date(2003, 11, 14), datetime.date(2003, 11, 22), datetime.date(2003, 11, 20), 'Shipped', None, 484, 20),
#  (10185, datetime.date(2003, 11, 14), datetime.date(2003, 11, 21), datetime.date(2003, 11, 20), 'Shipped', None, 320, 20),
#  (10186, datetime.date(2003, 11, 14), datetime.date(2003, 11, 20), datetime.date(2003, 11, 18), 'Shipped', 'They want to reevaluate their terms agreement with the VP of Sales', 489, 20),
#  (10187, datetime.date(2003, 11, 15), datetime.date(2003, 11, 24), datetime.date(2003, 11, 16), 'Shipped', None, 211, 20),
#  (10188, datetime.date(2003, 11, 18), datetime.date(2003, 11, 26), datetime.date(2003, 11, 24), 'Shipped', None, 167, 20),
#  (10189, datetime.date(2003, 11, 18), datetime.date(2003, 11, 25), datetime.date(2003, 11, 24), 'Shipped', 'They want to reevaluate their terms agreement with Finance.', 205, 20),
#  (10190, datetime.date(2003, 11, 19), datetime.date(2003, 11, 29), datetime.date(2003, 11, 20), 'Shipped', None, 141, 20),
#  (10191, datetime.date(2003, 11, 20), datetime.date(2003, 11, 30), datetime.date(2003, 11, 24), 'Shipped', 'We must be cautions with this customer. Their VP of Sales resigned. Company may be heading down.', 259, 20),
#  (10192, datetime.date(2003, 11, 20), datetime.date(2003, 11, 29), datetime.date(2003, 11, 25), 'Shipped', None, 363, 20),
#  (10193, datetime.date(2003, 11, 21), datetime.date(2003, 11, 28), datetime.date(2003, 11, 27), 'Shipped', None, 471, 20),
#  (10194, datetime.date(2003, 11, 25), datetime.date(2003, 12, 2), datetime.date(2003, 11, 26), 'Shipped', None, 146, 20),
#  (10195, datetime.date(2003, 11, 25), datetime.date(2003, 12, 1), datetime.date(2003, 11, 28), 'Shipped', None, 319, 20),
#  (10196, datetime.date(2003, 11, 26), datetime.date(2003, 12, 3), datetime.date(2003, 12, 1), 'Shipped', None, 455, 20),
#  (10197, datetime.date(2003, 11, 26), datetime.date(2003, 12, 2), datetime.date(2003, 12, 1), 'Shipped', 'Customer inquired about remote controlled models and gold models.', 216, 20),
#  (10198, datetime.date(2003, 11, 27), datetime.date(2003, 12, 6), datetime.date(2003, 12, 3), 'Shipped', None, 385, 20),
#  (10199, datetime.date(2003, 12, 1), datetime.date(2003, 12, 10), datetime.date(2003, 12, 6), 'Shipped', None, 475, 20),
#  (10200, datetime.date(2003, 12, 1), datetime.date(2003, 12, 9), datetime.date(2003, 12, 6), 'Shipped', None, 211, 20),
#  (10201, datetime.date(2003, 12, 1), datetime.date(2003, 12, 11), datetime.date(2003, 12, 2), 'Shipped', None, 129, 20),
#  (10202, datetime.date(2003, 12, 2), datetime.date(2003, 12, 9), datetime.date(2003, 12, 6), 'Shipped', None, 357, 20),
#  (10203, datetime.date(2003, 12, 2), datetime.date(2003, 12, 11), datetime.date(2003, 12, 7), 'Shipped', None, 141, 20),
#  (10204, datetime.date(2003, 12, 2), datetime.date(2003, 12, 10), datetime.date(2003, 12, 4), 'Shipped', None, 151, 20),
#  (10205, datetime.date(2003, 12, 3), datetime.date(2003, 12, 9), datetime.date(2003, 12, 7), 'Shipped', ' I need all the information I can get on our competitors.', 141, 20),
#  (10206, datetime.date(2003, 12, 5), datetime.date(2003, 12, 13), datetime.date(2003, 12, 8), 'Shipped', 'Can we renegotiate this one?', 202, 20),
#  (10207, datetime.date(2003, 12, 9), datetime.date(2003, 12, 17), datetime.date(2003, 12, 11), 'Shipped', 'Check on availability.', 495, 20),
#  (10208, datetime.date(2004, 1, 2), datetime.date(2004, 1, 11), datetime.date(2004, 1, 4), 'Shipped', None, 146, 19),
#  (10209, datetime.date(2004, 1, 9), datetime.date(2004, 1, 15), datetime.date(2004, 1, 12), 'Shipped', None, 347, 19),
#  (10210, datetime.date(2004, 1, 12), datetime.date(2004, 1, 22), datetime.date(2004, 1, 20), 'Shipped', None, 177, 19),
#  (10211, datetime.date(2004, 1, 15), datetime.date(2004, 1, 25), datetime.date(2004, 1, 18), 'Shipped', None, 406, 19),
#  (10212, datetime.date(2004, 1, 16), datetime.date(2004, 1, 24), datetime.date(2004, 1, 18), 'Shipped', None, 141, 19),
#  (10213, datetime.date(2004, 1, 22), datetime.date(2004, 1, 28), datetime.date(2004, 1, 27), 'Shipped', 'Difficult to negotiate with customer. We need more marketing materials', 489, 19),
#  (10214, datetime.date(2004, 1, 26), datetime.date(2004, 2, 4), datetime.date(2004, 1, 29), 'Shipped', None, 458, 19),
#  (10215, datetime.date(2004, 1, 29), datetime.date(2004, 2, 8), datetime.date(2004, 2, 1), 'Shipped', 'Customer requested that FedEx Ground is used for this shipping', 475, 19),
#  (10216, datetime.date(2004, 2, 2), datetime.date(2004, 2, 10), datetime.date(2004, 2, 4), 'Shipped', None, 256, 19),
#  (10217, datetime.date(2004, 2, 4), datetime.date(2004, 2, 14), datetime.date(2004, 2, 6), 'Shipped', None, 166, 19),
#  (10218, datetime.date(2004, 2, 9), datetime.date(2004, 2, 16), datetime.date(2004, 2, 11), 'Shipped', 'Customer requested that ad materials (such as posters, pamphlets) be included in the shippment', 473, 19),
#  (10219, datetime.date(2004, 2, 10), datetime.date(2004, 2, 17), datetime.date(2004, 2, 12), 'Shipped', None, 487, 19),
#  (10220, datetime.date(2004, 2, 12), datetime.date(2004, 2, 19), datetime.date(2004, 2, 16), 'Shipped', None, 189, 19),
#  (10221, datetime.date(2004, 2, 18), datetime.date(2004, 2, 26), datetime.date(2004, 2, 19), 'Shipped', None, 314, 19),
#  (10222, datetime.date(2004, 2, 19), datetime.date(2004, 2, 27), datetime.date(2004, 2, 20), 'Shipped', None, 239, 19),
#  (10223, datetime.date(2004, 2, 20), datetime.date(2004, 2, 29), datetime.date(2004, 2, 24), 'Shipped', None, 114, 19),
#  (10224, datetime.date(2004, 2, 21), datetime.date(2004, 3, 2), datetime.date(2004, 2, 26), 'Shipped', 'Customer has worked with some of our vendors in the past and is aware of their MSRP', 171, 19),
#  (10225, datetime.date(2004, 2, 22), datetime.date(2004, 3, 1), datetime.date(2004, 2, 24), 'Shipped', None, 298, 19),
#  (10226, datetime.date(2004, 2, 26), datetime.date(2004, 3, 6), datetime.date(2004, 3, 2), 'Shipped', None, 239, 19),
#  (10227, datetime.date(2004, 3, 2), datetime.date(2004, 3, 12), datetime.date(2004, 3, 8), 'Shipped', None, 146, 19),
#  (10228, datetime.date(2004, 3, 10), datetime.date(2004, 3, 18), datetime.date(2004, 3, 13), 'Shipped', None, 173, 19),
#  (10229, datetime.date(2004, 3, 11), datetime.date(2004, 3, 20), datetime.date(2004, 3, 12), 'Shipped', None, 124, 19),
#  (10230, datetime.date(2004, 3, 15), datetime.date(2004, 3, 24), datetime.date(2004, 3, 20), 'Shipped', 'Customer very concerned about the exact color of the models. There is high risk that he may dispute the order because there is a slight color mismatch', 128, 19),
#  (10231, datetime.date(2004, 3, 19), datetime.date(2004, 3, 26), datetime.date(2004, 3, 25), 'Shipped', None, 344, 19),
#  (10232, datetime.date(2004, 3, 20), datetime.date(2004, 3, 30), datetime.date(2004, 3, 25), 'Shipped', None, 240, 19),
#  (10233, datetime.date(2004, 3, 29), datetime.date(2004, 4, 4), datetime.date(2004, 4, 2), 'Shipped', 'Customer requested special shippment. The instructions were passed along to the warehouse', 328, 19),
#  (10234, datetime.date(2004, 3, 30), datetime.date(2004, 4, 5), datetime.date(2004, 4, 2), 'Shipped', None, 412, 19),
#  (10235, datetime.date(2004, 4, 2), datetime.date(2004, 4, 12), datetime.date(2004, 4, 6), 'Shipped', None, 260, 19),
#  (10236, datetime.date(2004, 4, 3), datetime.date(2004, 4, 11), datetime.date(2004, 4, 8), 'Shipped', None, 486, 19),
#  (10237, datetime.date(2004, 4, 5), datetime.date(2004, 4, 12), datetime.date(2004, 4, 10), 'Shipped', None, 181, 19),
#  (10238, datetime.date(2004, 4, 9), datetime.date(2004, 4, 16), datetime.date(2004, 4, 10), 'Shipped', None, 145, 19),
#  (10239, datetime.date(2004, 4, 12), datetime.date(2004, 4, 21), datetime.date(2004, 4, 17), 'Shipped', None, 311, 19),
#  (10240, datetime.date(2004, 4, 13), datetime.date(2004, 4, 20), datetime.date(2004, 4, 20), 'Shipped', None, 177, 19),
#  (10241, datetime.date(2004, 4, 13), datetime.date(2004, 4, 20), datetime.date(2004, 4, 19), 'Shipped', None, 209, 19),
#  (10242, datetime.date(2004, 4, 20), datetime.date(2004, 4, 28), datetime.date(2004, 4, 25), 'Shipped', 'Customer is interested in buying more Ferrari models', 456, 19),
#  (10243, datetime.date(2004, 4, 26), datetime.date(2004, 5, 3), datetime.date(2004, 4, 28), 'Shipped', None, 495, 19),
#  (10244, datetime.date(2004, 4, 29), datetime.date(2004, 5, 9), datetime.date(2004, 5, 4), 'Shipped', None, 141, 19),
#  (10245, datetime.date(2004, 5, 4), datetime.date(2004, 5, 12), datetime.date(2004, 5, 9), 'Shipped', None, 455, 19),
#  (10246, datetime.date(2004, 5, 5), datetime.date(2004, 5, 13), datetime.date(2004, 5, 6), 'Shipped', None, 141, 19),
#  (10247, datetime.date(2004, 5, 5), datetime.date(2004, 5, 11), datetime.date(2004, 5, 8), 'Shipped', None, 334, 19),
#  (10248, datetime.date(2004, 5, 7), datetime.date(2004, 5, 14), None, 'Cancelled', 'Order was mistakenly placed. The warehouse noticed the lack of documentation.', 131, 19),
#  (10249, datetime.date(2004, 5, 8), datetime.date(2004, 5, 17), datetime.date(2004, 5, 11), 'Shipped', 'Can we deliver the new Ford Mustang models by end-of-quarter?', 173, 19),
#  (10250, datetime.date(2004, 5, 11), datetime.date(2004, 5, 19), datetime.date(2004, 5, 15), 'Shipped', None, 450, 19),
#  (10251, datetime.date(2004, 5, 18), datetime.date(2004, 5, 24), datetime.date(2004, 5, 24), 'Shipped', None, 328, 19),
#  (10252, datetime.date(2004, 5, 26), datetime.date(2004, 6, 4), datetime.date(2004, 5, 29), 'Shipped', None, 406, 19),
#  (10253, datetime.date(2004, 6, 1), datetime.date(2004, 6, 9), datetime.date(2004, 6, 2), 'Cancelled', 'Customer disputed the order and we agreed to cancel it. We must be more cautions with this customer going forward, since they are very hard to please. We must cover the shipping fees.', 201, 19),
#  (10254, datetime.date(2004, 6, 3), datetime.date(2004, 6, 13), datetime.date(2004, 6, 4), 'Shipped', 'Customer requested that DHL is used for this shipping', 323, 19),
#  (10255, datetime.date(2004, 6, 4), datetime.date(2004, 6, 12), datetime.date(2004, 6, 9), 'Shipped', None, 209, 19),
#  (10256, datetime.date(2004, 6, 8), datetime.date(2004, 6, 16), datetime.date(2004, 6, 10), 'Shipped', None, 145, 19),
#  (10257, datetime.date(2004, 6, 14), datetime.date(2004, 6, 24), datetime.date(2004, 6, 15), 'Shipped', None, 450, 19),
#  (10258, datetime.date(2004, 6, 15), datetime.date(2004, 6, 25), datetime.date(2004, 6, 23), 'Shipped', None, 398, 19),
#  (10259, datetime.date(2004, 6, 15), datetime.date(2004, 6, 22), datetime.date(2004, 6, 17), 'Shipped', None, 166, 19),
#  (10260, datetime.date(2004, 6, 16), datetime.date(2004, 6, 22), None, 'Cancelled', 'Customer heard complaints from their customers and called to cancel this order. Will notify the Sales Manager.', 357, 19),
#  (10261, datetime.date(2004, 6, 17), datetime.date(2004, 6, 25), datetime.date(2004, 6, 22), 'Shipped', None, 233, 19),
#  (10262, datetime.date(2004, 6, 24), datetime.date(2004, 7, 1), None, 'Cancelled', 'This customer found a better offer from one of our competitors. Will call back to renegotiate.', 141, 19),
#  (10263, datetime.date(2004, 6, 28), datetime.date(2004, 7, 4), datetime.date(2004, 7, 2), 'Shipped', None, 175, 19),
#  (10264, datetime.date(2004, 6, 30), datetime.date(2004, 7, 6), datetime.date(2004, 7, 1), 'Shipped', 'Customer will send a truck to our local warehouse on 7/1/2004', 362, 19),
#  (10265, datetime.date(2004, 7, 2), datetime.date(2004, 7, 9), datetime.date(2004, 7, 7), 'Shipped', None, 471, 19),
#  (10266, datetime.date(2004, 7, 6), datetime.date(2004, 7, 14), datetime.date(2004, 7, 10), 'Shipped', None, 386, 19),
#  (10267, datetime.date(2004, 7, 7), datetime.date(2004, 7, 17), datetime.date(2004, 7, 9), 'Shipped', None, 151, 19),
#  (10268, datetime.date(2004, 7, 12), datetime.date(2004, 7, 18), datetime.date(2004, 7, 14), 'Shipped', None, 412, 19),
#  (10269, datetime.date(2004, 7, 16), datetime.date(2004, 7, 22), datetime.date(2004, 7, 18), 'Shipped', None, 382, 19),
#  (10270, datetime.date(2004, 7, 19), datetime.date(2004, 7, 27), datetime.date(2004, 7, 24), 'Shipped', 'Can we renegotiate this one?', 282, 19),
#  (10271, datetime.date(2004, 7, 20), datetime.date(2004, 7, 29), datetime.date(2004, 7, 23), 'Shipped', None, 124, 19),
#  (10272, datetime.date(2004, 7, 20), datetime.date(2004, 7, 26), datetime.date(2004, 7, 22), 'Shipped', None, 157, 19),
#  (10273, datetime.date(2004, 7, 21), datetime.date(2004, 7, 28), datetime.date(2004, 7, 22), 'Shipped', None, 314, 19),
#  (10274, datetime.date(2004, 7, 21), datetime.date(2004, 7, 29), datetime.date(2004, 7, 22), 'Shipped', None, 379, 19),
#  (10275, datetime.date(2004, 7, 23), datetime.date(2004, 8, 2), datetime.date(2004, 7, 29), 'Shipped', None, 119, 19),
#  (10276, datetime.date(2004, 8, 2), datetime.date(2004, 8, 11), datetime.date(2004, 8, 8), 'Shipped', None, 204, 19),
#  (10277, datetime.date(2004, 8, 4), datetime.date(2004, 8, 12), datetime.date(2004, 8, 5), 'Shipped', None, 148, 19),
#  (10278, datetime.date(2004, 8, 6), datetime.date(2004, 8, 16), datetime.date(2004, 8, 9), 'Shipped', None, 112, 19),
#  (10279, datetime.date(2004, 8, 9), datetime.date(2004, 8, 19), datetime.date(2004, 8, 15), 'Shipped', 'Cautious optimism. We have happy customers here, if we can keep them well stocked.  I need all the information I can get on the planned shippments of Porches', 141, 19),
#  (10280, datetime.date(2004, 8, 17), datetime.date(2004, 8, 27), datetime.date(2004, 8, 19), 'Shipped', None, 249, 19),
#  (10281, datetime.date(2004, 8, 19), datetime.date(2004, 8, 28), datetime.date(2004, 8, 23), 'Shipped', None, 157, 19),
#  (10282, datetime.date(2004, 8, 20), datetime.date(2004, 8, 26), datetime.date(2004, 8, 22), 'Shipped', None, 124, 19),
#  (10283, datetime.date(2004, 8, 20), datetime.date(2004, 8, 30), datetime.date(2004, 8, 23), 'Shipped', None, 260, 19),
#  (10284, datetime.date(2004, 8, 21), datetime.date(2004, 8, 29), datetime.date(2004, 8, 26), 'Shipped', 'Custom shipping instructions sent to warehouse', 299, 19),
#  (10285, datetime.date(2004, 8, 27), datetime.date(2004, 9, 4), datetime.date(2004, 8, 31), 'Shipped', None, 286, 19),
#  (10286, datetime.date(2004, 8, 28), datetime.date(2004, 9, 6), datetime.date(2004, 9, 1), 'Shipped', None, 172, 19),
#  (10287, datetime.date(2004, 8, 30), datetime.date(2004, 9, 6), datetime.date(2004, 9, 1), 'Shipped', None, 298, 19),
#  (10288, datetime.date(2004, 9, 1), datetime.date(2004, 9, 11), datetime.date(2004, 9, 5), 'Shipped', None, 166, 19),
#  (10289, datetime.date(2004, 9, 3), datetime.date(2004, 9, 13), datetime.date(2004, 9, 4), 'Shipped', 'We need to keep in close contact with their Marketing VP. He is the decision maker for all their purchases.', 167, 19),
#  (10290, datetime.date(2004, 9, 7), datetime.date(2004, 9, 15), datetime.date(2004, 9, 13), 'Shipped', None, 198, 19),
#  (10291, datetime.date(2004, 9, 8), datetime.date(2004, 9, 17), datetime.date(2004, 9, 14), 'Shipped', None, 448, 19),
#  (10292, datetime.date(2004, 9, 8), datetime.date(2004, 9, 18), datetime.date(2004, 9, 11), 'Shipped', 'They want to reevaluate their terms agreement with Finance.', 131, 19),
#  (10293, datetime.date(2004, 9, 9), datetime.date(2004, 9, 18), datetime.date(2004, 9, 14), 'Shipped', None, 249, 19),
#  (10294, datetime.date(2004, 9, 10), datetime.date(2004, 9, 17), datetime.date(2004, 9, 14), 'Shipped', None, 204, 19),
#  (10295, datetime.date(2004, 9, 10), datetime.date(2004, 9, 17), datetime.date(2004, 9, 14), 'Shipped', 'They want to reevaluate their terms agreement with Finance.', 362, 19),
#  (10296, datetime.date(2004, 9, 15), datetime.date(2004, 9, 22), datetime.date(2004, 9, 16), 'Shipped', None, 415, 19),
#  (10297, datetime.date(2004, 9, 16), datetime.date(2004, 9, 22), datetime.date(2004, 9, 21), 'Shipped', 'We must be cautions with this customer. Their VP of Sales resigned. Company may be heading down.', 189, 19),
#  (10298, datetime.date(2004, 9, 27), datetime.date(2004, 10, 5), datetime.date(2004, 10, 1), 'Shipped', None, 103, 19),
#  (10299, datetime.date(2004, 9, 30), datetime.date(2004, 10, 10), datetime.date(2004, 10, 1), 'Shipped', None, 186, 19),
#  (10300, datetime.date(2003, 10, 4), datetime.date(2003, 10, 13), datetime.date(2003, 10, 9), 'Shipped', None, 128, 20),
#  (10301, datetime.date(2003, 10, 5), datetime.date(2003, 10, 15), datetime.date(2003, 10, 8), 'Shipped', None, 299, 20),
#  (10302, datetime.date(2003, 10, 6), datetime.date(2003, 10, 16), datetime.date(2003, 10, 7), 'Shipped', None, 201, 20),
#  (10303, datetime.date(2004, 10, 6), datetime.date(2004, 10, 14), datetime.date(2004, 10, 9), 'Shipped', 'Customer inquired about remote controlled models and gold models.', 484, 19),
#  (10304, datetime.date(2004, 10, 11), datetime.date(2004, 10, 20), datetime.date(2004, 10, 17), 'Shipped', None, 256, 19),
#  (10305, datetime.date(2004, 10, 13), datetime.date(2004, 10, 22), datetime.date(2004, 10, 15), 'Shipped', 'Check on availability.', 286, 19),
#  (10306, datetime.date(2004, 10, 14), datetime.date(2004, 10, 21), datetime.date(2004, 10, 17), 'Shipped', None, 187, 19),
#  (10307, datetime.date(2004, 10, 14), datetime.date(2004, 10, 23), datetime.date(2004, 10, 20), 'Shipped', None, 339, 19),
#  (10308, datetime.date(2004, 10, 15), datetime.date(2004, 10, 24), datetime.date(2004, 10, 20), 'Shipped', 'Customer requested that FedEx Ground is used for this shipping', 319, 19),
#  (10309, datetime.date(2022, 3, 8), datetime.date(2004, 10, 24), datetime.date(2004, 10, 18), 'Shipped', None, 121, 19),
#  (10310, datetime.date(2004, 10, 16), datetime.date(2004, 10, 24), datetime.date(2004, 10, 18), 'Shipped', None, 259, 19),
#  (10311, datetime.date(2004, 10, 16), datetime.date(2004, 10, 23), datetime.date(2004, 10, 20), 'Shipped', 'Difficult to negotiate with customer. We need more marketing materials', 141, 19),
#  (10312, datetime.date(2004, 10, 21), datetime.date(2004, 10, 27), datetime.date(2004, 10, 23), 'Shipped', None, 124, 19),
#  (10313, datetime.date(2004, 10, 22), datetime.date(2004, 10, 28), datetime.date(2004, 10, 25), 'Shipped', 'Customer requested that FedEx Ground is used for this shipping', 202, 19),
#  (10314, datetime.date(2004, 10, 22), datetime.date(2004, 11, 1), datetime.date(2004, 10, 23), 'Shipped', None, 227, 19),
#  (10315, datetime.date(2004, 10, 29), datetime.date(2004, 11, 8), datetime.date(2004, 10, 30), 'Shipped', None, 119, 19),
#  (10316, datetime.date(2004, 11, 1), datetime.date(2004, 11, 9), datetime.date(2004, 11, 7), 'Shipped', 'Customer requested that ad materials (such as posters, pamphlets) be included in the shippment', 240, 19),
#  (10317, datetime.date(2004, 11, 2), datetime.date(2004, 11, 12), datetime.date(2004, 11, 8), 'Shipped', None, 161, 19),
#  (10318, datetime.date(2004, 11, 2), datetime.date(2004, 11, 9), datetime.date(2004, 11, 7), 'Shipped', None, 157, 19),
#  (10319, datetime.date(2004, 11, 3), datetime.date(2004, 11, 11), datetime.date(2004, 11, 6), 'Shipped', 'Customer requested that DHL is used for this shipping', 456, 19),
#  (10320, datetime.date(2004, 11, 3), datetime.date(2004, 11, 13), datetime.date(2004, 11, 7), 'Shipped', None, 144, 19),
#  (10321, datetime.date(2004, 11, 4), datetime.date(2004, 11, 12), datetime.date(2004, 11, 7), 'Shipped', None, 462, 19),
#  (10322, datetime.date(2004, 11, 4), datetime.date(2004, 11, 12), datetime.date(2004, 11, 10), 'Shipped', 'Customer has worked with some of our vendors in the past and is aware of their MSRP', 363, 19),
#  (10323, datetime.date(2004, 11, 5), datetime.date(2004, 11, 12), datetime.date(2004, 11, 9), 'Shipped', None, 128, 19),
#  (10324, datetime.date(2004, 11, 5), datetime.date(2004, 11, 11), datetime.date(2004, 11, 8), 'Shipped', None, 181, 19),
#  (10325, datetime.date(2022, 3, 8), datetime.date(2004, 11, 13), datetime.date(2004, 11, 8), 'Shipped', None, 121, 19),
#  (10326, datetime.date(2004, 11, 9), datetime.date(2004, 11, 16), datetime.date(2004, 11, 10), 'Shipped', None, 144, 19),
#  (10327, datetime.date(2004, 11, 10), datetime.date(2004, 11, 19), datetime.date(2004, 11, 13), 'Resolved', "Order was disputed and resolved on 12/1/04. The Sales Manager was involved. Customer claims the scales of the models don't match what was discussed.", 145, 19),
#  (10328, datetime.date(2004, 11, 12), datetime.date(2004, 11, 21), datetime.date(2004, 11, 18), 'Shipped', 'Customer very concerned about the exact color of the models. There is high risk that he may dispute the order because there is a slight color mismatch', 278, 19),
#  (10329, datetime.date(2004, 11, 15), datetime.date(2004, 11, 24), datetime.date(2004, 11, 16), 'Shipped', None, 131, 19),
#  (10330, datetime.date(2004, 11, 16), datetime.date(2004, 11, 25), datetime.date(2004, 11, 21), 'Shipped', None, 385, 19),
#  (10331, datetime.date(2004, 11, 17), datetime.date(2004, 11, 23), datetime.date(2004, 11, 23), 'Shipped', 'Customer requested special shippment. The instructions were passed along to the warehouse', 486, 19),
#  (10332, datetime.date(2004, 11, 17), datetime.date(2004, 11, 25), datetime.date(2004, 11, 18), 'Shipped', None, 187, 19),
#  (10333, datetime.date(2004, 11, 18), datetime.date(2004, 11, 27), datetime.date(2004, 11, 20), 'Shipped', None, 129, 19),
#  (10334, datetime.date(2004, 11, 19), datetime.date(2004, 11, 28), None, 'On Hold', 'The outstaniding balance for this customer exceeds their credit limit. Order will be shipped when a payment is received.', 144, 19),
#  (10335, datetime.date(2004, 11, 19), datetime.date(2004, 11, 29), datetime.date(2004, 11, 23), 'Shipped', None, 124, 19),
#  (10336, datetime.date(2004, 11, 20), datetime.date(2004, 11, 26), datetime.date(2004, 11, 24), 'Shipped', 'Customer requested that DHL is used for this shipping', 172, 19),
#  (10337, datetime.date(2004, 11, 21), datetime.date(2004, 11, 30), datetime.date(2004, 11, 26), 'Shipped', None, 424, 19),
#  (10338, datetime.date(2004, 11, 22), datetime.date(2004, 12, 2), datetime.date(2004, 11, 27), 'Shipped', None, 381, 19),
#  (10339, datetime.date(2004, 11, 23), datetime.date(2004, 11, 30), datetime.date(2004, 11, 30), 'Shipped', None, 398, 19),
#  (10340, datetime.date(2004, 11, 24), datetime.date(2004, 12, 1), datetime.date(2004, 11, 25), 'Shipped', 'Customer is interested in buying more Ferrari models', 216, 19),
#  (10341, datetime.date(2004, 11, 24), datetime.date(2004, 12, 1), datetime.date(2004, 11, 29), 'Shipped', None, 382, 19),
#  (10342, datetime.date(2004, 11, 24), datetime.date(2004, 12, 1), datetime.date(2004, 11, 29), 'Shipped', None, 114, 19),
#  (10343, datetime.date(2004, 11, 24), datetime.date(2004, 12, 1), datetime.date(2004, 11, 26), 'Shipped', None, 353, 19),
#  (10344, datetime.date(2004, 11, 25), datetime.date(2004, 12, 2), datetime.date(2004, 11, 29), 'Shipped', None, 350, 19),
#  (10345, datetime.date(2004, 11, 25), datetime.date(2004, 12, 1), datetime.date(2004, 11, 26), 'Shipped', None, 103, 19),
#  (10346, datetime.date(2004, 11, 29), datetime.date(2004, 12, 5), datetime.date(2004, 11, 30), 'Shipped', None, 112, 19),
#  (10347, datetime.date(2004, 11, 29), datetime.date(2004, 12, 7), datetime.date(2004, 11, 30), 'Shipped', 'Can we deliver the new Ford Mustang models by end-of-quarter?', 114, 19),
#  (10348, datetime.date(2004, 11, 1), datetime.date(2004, 11, 8), datetime.date(2004, 11, 5), 'Shipped', None, 458, 19),
#  (10349, datetime.date(2004, 12, 1), datetime.date(2004, 12, 7), datetime.date(2004, 12, 3), 'Shipped', None, 151, 19),
#  (10350, datetime.date(2004, 12, 2), datetime.date(2004, 12, 8), datetime.date(2004, 12, 5), 'Shipped', None, 141, 19),
#  (10351, datetime.date(2004, 12, 3), datetime.date(2004, 12, 11), datetime.date(2004, 12, 7), 'Shipped', None, 324, 19),
#  (10352, datetime.date(2004, 12, 3), datetime.date(2004, 12, 12), datetime.date(2004, 12, 9), 'Shipped', None, 198, 19),
#  (10353, datetime.date(2004, 12, 4), datetime.date(2004, 12, 11), datetime.date(2004, 12, 5), 'Shipped', None, 447, 19),
#  (10354, datetime.date(2004, 12, 4), datetime.date(2004, 12, 10), datetime.date(2004, 12, 5), 'Shipped', None, 323, 19),
#  (10355, datetime.date(2004, 12, 7), datetime.date(2004, 12, 14), datetime.date(2004, 12, 13), 'Shipped', None, 141, 19),
#  (10356, datetime.date(2004, 12, 9), datetime.date(2004, 12, 15), datetime.date(2004, 12, 12), 'Shipped', None, 250, 19),
#  (10357, datetime.date(2004, 12, 10), datetime.date(2004, 12, 16), datetime.date(2004, 12, 14), 'Shipped', None, 124, 19),
#  (10358, datetime.date(2004, 12, 10), datetime.date(2004, 12, 16), datetime.date(2004, 12, 16), 'Shipped', 'Customer requested that DHL is used for this shipping', 141, 19),
#  (10359, datetime.date(2004, 12, 15), datetime.date(2004, 12, 23), datetime.date(2004, 12, 18), 'Shipped', None, 353, 19),
#  (10360, datetime.date(2004, 12, 16), datetime.date(2004, 12, 22), datetime.date(2004, 12, 18), 'Shipped', None, 496, 19),
#  (10361, datetime.date(2004, 12, 17), datetime.date(2004, 12, 24), datetime.date(2004, 12, 20), 'Shipped', None, 282, 19),
#  (10362, datetime.date(2005, 1, 5), datetime.date(2005, 1, 16), datetime.date(2005, 1, 10), 'Shipped', None, 161, 18),
#  (10363, datetime.date(2005, 1, 6), datetime.date(2005, 1, 12), datetime.date(2005, 1, 10), 'Shipped', None, 334, 18),
#  (10364, datetime.date(2005, 1, 6), datetime.date(2005, 1, 17), datetime.date(2005, 1, 9), 'Shipped', None, 350, 18),
#  (10365, datetime.date(2005, 1, 7), datetime.date(2005, 1, 18), datetime.date(2005, 1, 11), 'Shipped', None, 320, 18),
#  (10366, datetime.date(2005, 1, 10), datetime.date(2005, 1, 19), datetime.date(2005, 1, 12), 'Shipped', None, 381, 18),
#  (10367, datetime.date(2005, 1, 12), datetime.date(2005, 1, 21), datetime.date(2005, 1, 16), 'Resolved', "This order was disputed and resolved on 2/1/2005. Customer claimed that container with shipment was damaged. FedEx's investigation proved this wrong.", 205, 18),
#  (10368, datetime.date(2005, 1, 19), datetime.date(2005, 1, 27), datetime.date(2005, 1, 24), 'Shipped', 'Can we renegotiate this one?', 124, 18),
#  (10369, datetime.date(2005, 1, 20), datetime.date(2005, 1, 28), datetime.date(2005, 1, 24), 'Shipped', None, 379, 18),
#  (10370, datetime.date(2005, 1, 20), datetime.date(2005, 2, 1), datetime.date(2005, 1, 25), 'Shipped', None, 276, 18),
#  (10371, datetime.date(2005, 1, 23), datetime.date(2005, 2, 3), datetime.date(2005, 1, 25), 'Shipped', None, 124, 18),
#  (10372, datetime.date(2005, 1, 26), datetime.date(2005, 2, 5), datetime.date(2005, 1, 28), 'Shipped', None, 398, 18),
#  (10373, datetime.date(2005, 1, 31), datetime.date(2005, 2, 8), datetime.date(2005, 2, 6), 'Shipped', None, 311, 18),
#  (10374, datetime.date(2005, 2, 2), datetime.date(2005, 2, 9), datetime.date(2005, 2, 3), 'Shipped', None, 333, 18),
#  (10375, datetime.date(2005, 2, 3), datetime.date(2005, 2, 10), datetime.date(2005, 2, 6), 'Shipped', None, 119, 18),
#  (10376, datetime.date(2005, 2, 8), datetime.date(2005, 2, 18), datetime.date(2005, 2, 13), 'Shipped', None, 219, 18),
#  (10377, datetime.date(2005, 2, 9), datetime.date(2005, 2, 21), datetime.date(2005, 2, 12), 'Shipped', 'Cautious optimism. We have happy customers here, if we can keep them well stocked.  I need all the information I can get on the planned shippments of Porches', 186, 18),
#  (10378, datetime.date(2005, 2, 10), datetime.date(2005, 2, 18), datetime.date(2005, 2, 11), 'Shipped', None, 141, 18),
#  (10379, datetime.date(2005, 2, 10), datetime.date(2005, 2, 18), datetime.date(2005, 2, 11), 'Shipped', None, 141, 18),
#  (10380, datetime.date(2005, 2, 16), datetime.date(2005, 2, 24), datetime.date(2005, 2, 18), 'Shipped', None, 141, 18),
#  (10381, datetime.date(2005, 2, 17), datetime.date(2005, 2, 25), datetime.date(2005, 2, 18), 'Shipped', None, 321, 18),
#  (10382, datetime.date(2005, 2, 17), datetime.date(2005, 2, 23), datetime.date(2005, 2, 18), 'Shipped', 'Custom shipping instructions sent to warehouse', 124, 18),
#  (10383, datetime.date(2005, 2, 22), datetime.date(2005, 3, 2), datetime.date(2005, 2, 25), 'Shipped', None, 141, 18),
#  (10384, datetime.date(2005, 2, 23), datetime.date(2005, 3, 6), datetime.date(2005, 2, 27), 'Shipped', None, 321, 18),
#  (10385, datetime.date(2005, 2, 28), datetime.date(2005, 3, 9), datetime.date(2005, 3, 1), 'Shipped', None, 124, 18),
#  (10386, datetime.date(2005, 3, 1), datetime.date(2005, 3, 9), datetime.date(2005, 3, 6), 'Resolved', "Disputed then Resolved on 3/15/2005. Customer doesn't like the craftsmaship of the models.", 141, 18),
#  (10387, datetime.date(2005, 3, 2), datetime.date(2005, 3, 9), datetime.date(2005, 3, 6), 'Shipped', 'We need to keep in close contact with their Marketing VP. He is the decision maker for all their purchases.', 148, 18),
#  (10388, datetime.date(2005, 3, 3), datetime.date(2005, 3, 11), datetime.date(2005, 3, 9), 'Shipped', None, 462, 18),
#  (10389, datetime.date(2005, 3, 3), datetime.date(2005, 3, 9), datetime.date(2005, 3, 8), 'Shipped', None, 448, 18),
#  (10390, datetime.date(2005, 3, 4), datetime.date(2005, 3, 11), datetime.date(2005, 3, 7), 'Shipped', 'They want to reevaluate their terms agreement with Finance.', 124, 18),
#  (10391, datetime.date(2005, 3, 9), datetime.date(2005, 3, 20), datetime.date(2005, 3, 15), 'Shipped', None, 276, 18),
#  (10392, datetime.date(2005, 3, 10), datetime.date(2005, 3, 18), datetime.date(2005, 3, 12), 'Shipped', None, 452, 18),
#  (10393, datetime.date(2005, 3, 11), datetime.date(2005, 3, 22), datetime.date(2005, 3, 14), 'Shipped', 'They want to reevaluate their terms agreement with Finance.', 323, 18),
#  (10394, datetime.date(2005, 3, 15), datetime.date(2005, 3, 25), datetime.date(2005, 3, 19), 'Shipped', None, 141, 18),
#  (10395, datetime.date(2005, 3, 17), datetime.date(2005, 3, 24), datetime.date(2005, 3, 23), 'Shipped', 'We must be cautions with this customer. Their VP of Sales resigned. Company may be heading down.', 250, 18),
#  (10396, datetime.date(2005, 3, 23), datetime.date(2005, 4, 2), datetime.date(2005, 3, 28), 'Shipped', None, 124, 18),
#  (10397, datetime.date(2005, 3, 28), datetime.date(2005, 4, 9), datetime.date(2005, 4, 1), 'Shipped', None, 242, 18),
#  (10398, datetime.date(2005, 3, 30), datetime.date(2005, 4, 9), datetime.date(2005, 3, 31), 'Shipped', None, 353, 18),
#  (10399, datetime.date(2005, 4, 1), datetime.date(2005, 4, 12), datetime.date(2005, 4, 3), 'Shipped', None, 496, 18),
#  (10400, datetime.date(2005, 4, 1), datetime.date(2005, 4, 11), datetime.date(2005, 4, 4), 'Shipped', 'Customer requested that DHL is used for this shipping', 450, 18),
#  (10401, datetime.date(2005, 4, 3), datetime.date(2005, 4, 14), None, 'On Hold', 'Customer credit limit exceeded. Will ship when a payment is received.', 328, 18),
#  (10402, datetime.date(2005, 4, 7), datetime.date(2005, 4, 14), datetime.date(2005, 4, 12), 'Shipped', None, 406, 18),
#  (10403, datetime.date(2005, 4, 8), datetime.date(2005, 4, 18), datetime.date(2005, 4, 11), 'Shipped', None, 201, 18),
#  (10404, datetime.date(2005, 4, 8), datetime.date(2005, 4, 14), datetime.date(2005, 4, 11), 'Shipped', None, 323, 18),
#  (10405, datetime.date(2005, 4, 14), datetime.date(2005, 4, 24), datetime.date(2005, 4, 20), 'Shipped', None, 209, 18),
#  (10406, datetime.date(2005, 4, 15), datetime.date(2005, 4, 25), datetime.date(2005, 4, 21), 'Disputed', 'Customer claims container with shipment was damaged during shipping and some items were missing. I am talking to FedEx about this.', 145, 18),
#  (10407, datetime.date(2005, 4, 22), datetime.date(2005, 5, 4), None, 'On Hold', 'Customer credit limit exceeded. Will ship when a payment is received.', 450, 18),
#  (10408, datetime.date(2005, 4, 22), datetime.date(2005, 4, 29), datetime.date(2005, 4, 27), 'Shipped', None, 398, 18),
#  (10409, datetime.date(2005, 4, 23), datetime.date(2005, 5, 5), datetime.date(2005, 4, 24), 'Shipped', None, 166, 18),
#  (10410, datetime.date(2005, 4, 29), datetime.date(2005, 5, 10), datetime.date(2005, 4, 30), 'Shipped', None, 357, 18),
#  (10411, datetime.date(2005, 5, 1), datetime.date(2005, 5, 8), datetime.date(2005, 5, 6), 'Shipped', None, 233, 18),
#  (10412, datetime.date(2005, 5, 3), datetime.date(2005, 5, 13), datetime.date(2005, 5, 5), 'Shipped', None, 141, 18),
#  (10413, datetime.date(2005, 5, 5), datetime.date(2005, 5, 14), datetime.date(2005, 5, 9), 'Shipped', 'Customer requested that DHL is used for this shipping', 175, 18),
#  (10414, datetime.date(2005, 5, 6), datetime.date(2005, 5, 13), None, 'On Hold', 'Customer credit limit exceeded. Will ship when a payment is received.', 362, 18),
#  (10415, datetime.date(2005, 5, 9), datetime.date(2005, 5, 20), datetime.date(2005, 5, 12), 'Disputed', "Customer claims the scales of the models don't match what was discussed. I keep all the paperwork though to prove otherwise", 471, 18),
#  (10416, datetime.date(2005, 5, 10), datetime.date(2005, 5, 16), datetime.date(2005, 5, 14), 'Shipped', None, 386, 18),
#  (10417, datetime.date(2005, 5, 13), datetime.date(2005, 5, 19), datetime.date(2005, 5, 19), 'Disputed', "Customer doesn't like the colors and precision of the models.", 141, 18),
#  (10418, datetime.date(2005, 5, 16), datetime.date(2005, 5, 24), datetime.date(2005, 5, 20), 'Shipped', None, 412, 18),
#  (10419, datetime.date(2005, 5, 17), datetime.date(2005, 5, 28), datetime.date(2005, 5, 19), 'Shipped', None, 382, 18),
#  (10420, datetime.date(2005, 5, 29), datetime.date(2005, 6, 7), None, 'In Process', None, 282, 18),
#  (10421, datetime.date(2005, 5, 29), datetime.date(2005, 6, 6), None, 'In Process', 'Custom shipping instructions were sent to warehouse', 124, 18),
#  (10422, datetime.date(2005, 5, 30), datetime.date(2005, 6, 11), None, 'In Process', None, 157, 18),
#  (10423, datetime.date(2005, 5, 30), datetime.date(2005, 6, 5), None, 'In Process', None, 314, 18),
#  (10424, datetime.date(2005, 5, 31), datetime.date(2005, 6, 8), None, 'In Process', None, 141, 18),
#  (10425, datetime.date(2005, 5, 31), datetime.date(2005, 6, 7), None, 'In Process', None, 119, 18)]

# %% [markdown]
# # Create Trigger

# %%
# %sql DROP TABLE info_order
# Out:
# 0 rows affected.
# []

# %%
# %sql CREATE TABLE info_order(id int PRIMARY KEY auto_increment, date CHAR(50))
# Out:
# 0 rows affected.
# []

# %%
# %sql DROP TRIGGER after_orders_update
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TRIGGER after_orders_update
# AFTER UPDATE ON orders
# FOR EACH ROW
# BEGIN
# INSERT INTO info_order(date) VALUES(NOW());
# END
# Out:
# 0 rows affected.
# []

# %%
# %sql select * from orders WHERE customerNumber=121 limit 2
# Out:
# 2 rows affected.
# [(10103, datetime.date(2022, 3, 8), datetime.date(2003, 2, 7), datetime.date(2003, 2, 2), 'Shipped', None, 121, 20),
#  (10158, datetime.date(2022, 3, 8), datetime.date(2003, 10, 18), datetime.date(2003, 10, 15), 'Shipped', None, 121, 20)]

# %%
# %sql UPDATE orders SET orderDate='2022-03-08' WHERE customerNumber=121
# Out:
# 4 rows affected.
# []

# %%
# %sql SELECT * FROM info_order
# Out:
# 4 rows affected.
# [(1, '2023-05-10 15:26:35'),
#  (2, '2023-05-10 15:26:35'),
#  (3, '2023-05-10 15:26:35'),
#  (4, '2023-05-10 15:26:35')]

# %% [markdown]
# # Create procedure

# %%
# %%sql
# DROP PROCEDURE insert_column;
#
# ALTER TABLE payments
# DROP COLUMN year_past;
# Out:
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM payments limit 4
# Out:
# 4 rows affected.
# [(103, 'HQ336336', datetime.date(2004, 10, 19), Decimal('6066.78')),
#  (103, 'JM555205', datetime.date(2003, 6, 5), Decimal('14571.44')),
#  (103, 'OM314933', datetime.date(2004, 12, 18), Decimal('1676.14')),
#  (112, 'BO864823', datetime.date(2004, 12, 17), Decimal('14191.12'))]

# %%
# %%sql
# CREATE PROCEDURE insert_column()#without input and output
# BEGIN
#     ALTER TABLE payments
#     ADD COLUMN year_past INT;
#
#     UPDATE payments SET year_past=YEAR(NOW())-YEAR(paymentDate);
# END
# Out:
# 0 rows affected.
# []

# %%
# %%sql
#
# CALL insert_column()
# Out:
# 273 rows affected.
# []

# %%
# %sql SELECT * FROM payments limit 4
# Out:
# 4 rows affected.
# [(103, 'HQ336336', datetime.date(2004, 10, 19), Decimal('6066.78'), 19),
#  (103, 'JM555205', datetime.date(2003, 6, 5), Decimal('14571.44'), 20),
#  (103, 'OM314933', datetime.date(2004, 12, 18), Decimal('1676.14'), 19),
#  (112, 'BO864823', datetime.date(2004, 12, 17), Decimal('14191.12'), 19)]

# %%
# %%sql
# DROP PROCEDURE testprocedure;
#
#
# CREATE PROCEDURE testprocedure(In id INTEGER, OUT col INTEGER)
#     BEGIN
#      SELECT e1.firstName as name, e1.lastName as family, e2.firstName , e2.lastName
#          from employees as e1
#             LEFT JOIN employees as e2
#         on e2.employeeNumber = e1.reportsTo
#         WHERE e1.employeeNumber = id;
#     END
# Out:
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %sql SET @col=""
# %sql CALL testprocedure(1002, @col)
# Out:
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '' at line 1")
# [SQL: SET @col=]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 1 rows affected.
# [('Diane', 'Murphy', None, None)]

# %% [markdown]
# # Create transaction

# %%
# %%sql
# START TRANSACTION ;
# select * from orders;
# UPDATE test3 SET number_year=100 where name='ddd';
# COMMIT;
# Out:
# 0 rows affected.
# 326 rows affected.
# 1 rows affected.
# 0 rows affected.
# []
